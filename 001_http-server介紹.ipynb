# %% [markdown]
# 人類世界是一個龐大的訊息系統，每個人都是訊息的傳入與傳出點
#
# 有些人眉目傳情
#
# 有些人悄然攜手
#
# 總而言之，有很多傳遞方式

# %% [markdown]
# 資訊世界也差不多，每個電腦都可以是訊息的傳入與傳出點
#
# 有的時候，我們想收發email，會用smtp
#
# 有的時候，想跟別人共享檔案，會用ftp
#
# 而最常見的一種方式，是http，常見的網站協定

# %% [markdown]
# 每一種程式語言都能夠用套件，去表達http協定
#
# python語言最常見的一種套件，叫做flask
#
# 現在我們就來體驗一下吧

# %% [markdown]
# 體驗流程如下，但凡寫程式的流程似乎就這樣了
#
# 安裝套件
#
# 引用套件
#
# 建置主程序
#
# 為主程序製作交互API接口
#
# 啟動主程序

# %%
'''
安裝套件
'''
# !pip install line-bot-sdk flask flask-ngrok!pip install pyngrok!ngrok authtoken 你的ngrok authtoken!!!!

# %%
'''
引用套件
'''

# 引用flask Web Server套件
from flask import Flask, request, abort, jsonify

# 載入json處理套件
import json

# 外部連結自動生成套件
from flask_ngrok import run_with_ngrok

# %%
'''
建置主程序
'''

# 設定Server啟用細節
app = Flask(__name__,static_url_path = "/material" , static_folder = "./material/")
run_with_ngrok(app)

# %%
'''

為主程序創造多個API接口

想像思路
當外面的封包進來的時候，轉流到這個方法

'''
# 啟動主程序的API接口，最簡單版本
@app.route("/", methods=['GET'])
def callback():
     
    return 'Hello World'

# %%
# 第二隻接口，

# 啟動主程序的API接口，名為calculate，計算機功能，剖析v1參數與v2參數
@app.route("/calculate", methods=['GET'])
def calculate():
    first_parameter = int(request.args.get('v1'))
    second_parameter = int(request.args.get('v2'))
    return str(first_parameter+second_parameter)

# %%
# 啟動主程序
app.run()
